# %%
def fib(t):
    if t < 0: raise ValueError("I can't cope with a negative number here.")
    if (t == 0):
        return 0
    if (t == 1):
        return 1
    return(fib(t-1) + fib(t-2))

# %%
fib(0)
# Out:
# 0

# %%
fib(1)
# Out:
# 1

# %%
fib(2)
# Out:
# 1

# %%
fib(3)
# Out:
# 2

# %%
fib(4)
# Out:
# 3

# %%
fib(5)
# Out:
# 5

# %%
fib(6)
# Out:
# 8

# %%
fib(7)
# Out:
# 13

# %%
fib(-7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5f83e8c9b101> in <module>()
# ----> 1 fib(-7)
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       1 def fib(t):
# ----> 2     if t < 0: raise ValueError("I can't cope with a negative number here.")
#       3     if (t == 0):
#       4         return 0
#       5     if (t == 1):
#
# ValueError: I can't cope with a negative number here.

# %%
fib(100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-704a26a64b82> in <module>()
# ----> 1 fib(100)
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       5     if (t == 1):
#       6         return 1
# ----> 7     return(fib(t-1) + fib(t-2))
#       8
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       5     if (t == 1):
#       6         return 1
# ----> 7     return(fib(t-1) + fib(t-2))
#       8
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       5     if (t == 1):
#       6         return 1
# ----> 7     return(fib(t-1) + fib(t-2))
#       8
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       5     if (t == 1):
#       6         return 1
# ----> 7     return(fib(t-1) + fib(t-2))
#       8
#
# <ipython-input-23-3efd379a7d5e> in fib(t)
#       5     if (t == 1):
#       6         return 1
# ----> 7     return(fib(t-1) + fib(t-2))
#       8
#
# ...

# %%
fib(10)
# Out:
# 55

# %%
fib(32)
# Out:
# 2178309

# %%
fib(28)
# Out:
# 317811
